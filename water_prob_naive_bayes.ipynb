# %%
import pandas as pd
df = pd.read_csv('water_potability.csv')

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df['Potability'].value_counts()
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
df.fillna(df.median(), inplace=True)

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.074194   196.369496  22014.092526     7.122277   333.608364
# std       1.470040    32.879761   8768.570828     1.583085    36.143851
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.407478     3.966786     0.390110
# std       80.824064        3.308162        15.769958     0.780382     0.487849
# ...

# %%
df.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.075760 -0.082004    -0.031741  0.014178
# Hardness         0.075760  1.000000 -0.046899    -0.030054 -0.092833
# Solids          -0.082004 -0.046899  1.000000    -0.070148 -0.149747
# Chloramines     -0.031741 -0.030054 -0.070148     1.000000  0.023762
# Sulfate          0.014178 -0.092833 -0.149747     0.023762  1.000000
# Conductivity     0.017466 -0.023915  0.013831    -0.020486 -0.014182
# Organic_carbon   0.040240  0.003610  0.010242    -0.012653  0.027102
# Trihalomethanes  0.003145 -0.012707 -0.008799     0.016614 -0.025657
# Turbidity       -0.036107 -0.014449  0.019546     0.002363 -0.009767
# Potability      -0.003014 -0.013837  0.033743     0.023779 -0.020476
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.017466        0.040240         0.003145  -0.036107
# ...

# %%
# Visualize the target distribution
import matplotlib.pyplot as plt
df['Potability'].value_counts().plot(kind='bar')
plt.title('Potability Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for better-looking plots
sns.set_style("whitegrid")

# Plot distribution of all features
df.hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
# Pick a few important features to compare
features = ['ph', 'Hardness', 'Sulfate', 'Chloramines']

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

for idx, feature in enumerate(features):
    axes[idx].hist(df[df['Potability']==0][feature], alpha=0.5, label='Not Potable', bins=30)
    axes[idx].hist(df[df['Potability']==1][feature], alpha=0.5, label='Potable', bins=30)
    axes[idx].set_xlabel(feature)
    axes[idx].set_ylabel('Frequency')
    axes[idx].legend()
    
plt.tight_layout()
plt.show()

# %%
# See how features relate to each other
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Feature Correlations')
plt.show()

# %%
# Box plots for a few features
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

for idx, feature in enumerate(features):
    df.boxplot(column=feature, by='Potability', ax=axes[idx])
    axes[idx].set_title(f'{feature} by Potability')
    
plt.tight_layout()
plt.show()

# %%
df['hardness_solids_ratio'] = df['Hardness'] / (df['Solids'] + 1)  # +1 to avoid division by zero

# %%
# Function to detect outliers
def count_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = ((column < lower_bound) | (column > upper_bound)).sum()
    return outliers, lower_bound, upper_bound

features = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 
                     'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'hardness_solids_ratio']

print("Outlier Analysis:")
print("="*60)
for feature in features:
    outliers, lower, upper = count_outliers(df[feature])
    print(f"{feature:20} | Outliers: {outliers:4} | Range: [{lower:.2f}, {upper:.2f}]")
# Out:
# Outlier Analysis:
# ...
# ph                   | Outliers:  142 | Range: [3.89, 10.26]
# Hardness             | Outliers:   83 | Range: [117.13, 276.39]
# Solids               | Outliers:   47 | Range: [-1832.42, 44831.87]
# Chloramines          | Outliers:   61 | Range: [3.15, 11.10]
# Sulfate              | Outliers:  264 | Range: [267.16, 400.32]
# Conductivity         | Outliers:   11 | Range: [191.65, 655.88]
# Organic_carbon       | Outliers:   25 | Range: [5.33, 23.30]
# Trihalomethanes      | Outliers:   54 | Range: [26.62, 106.70]
# Turbidity            | Outliers:   19 | Range: [1.85, 6.09]
# hardness_solids_ratio | Outliers:  172 | Range: [-0.00, 0.02]

# %%
def cap_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column.clip(lower=lower_bound, upper=upper_bound)

# Apply to problematic features
df['Sulfate'] = cap_outliers(df['Sulfate'])
df['ph'] = cap_outliers(df['ph'])
df['Hardness'] = cap_outliers(df['Hardness'])
df['hardness_solids_ratio'] = cap_outliers(df['hardness_solids_ratio'])

# %%
from sklearn.model_selection import train_test_split

# Separate features and target
X = df.drop('Potability', axis=1)  # All columns except Potability
y = df['Potability']                # Only Potability column

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2,      # 20% for testing, 80% for training
    random_state=42,    # For reproducibility
    stratify=y          # Keeps the 61/39 ratio in both train and test
)

# %%
X_train.shape
# Out:
# (2620, 10)

# %%
X_test.shape
# Out:
# (656, 10)

# %%
y_train.shape
# Out:
# (2620,)

# %%
y_test.shape
# Out:
# (656,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model_scaled = GaussianNB()
model_scaled.fit(X_train_scaled, y_train)
# Out:
# GaussianNB()

# %%
# Predict on test set
y_pred_scaled = model_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Calculate accuracy on ALL test data
accuracy = accuracy_score(y_test, y_pred_scaled)
print(f"Accuracy: {accuracy:.4f}")

# Detailed metrics
print("\nClassification Report:")
print(classification_report(y_test, y_pred_scaled, target_names=['Not Potable', 'Potable']))

# Confusion matrix
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test, y_pred_scaled)
print(cm)
print("\nBreakdown:")
print(f"True Negatives (correct non-potable):  {cm[0,0]}")
print(f"False Positives (wrong potable):       {cm[0,1]}")
print(f"False Negatives (wrong non-potable):   {cm[1,0]}")
print(f"True Positives (correct potable):      {cm[1,1]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
#       3 # Calculate accuracy on ALL test data
# ----> 4 accuracy = accuracy_score(y_test, y_pred_scaled)
#       5 print(f"Accuracy: {accuracy:.4f}")
#       7 # Detailed metrics
#
# NameError: name 'y_test' is not defined
